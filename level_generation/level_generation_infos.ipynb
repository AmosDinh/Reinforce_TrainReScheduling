# %% [markdown]
# ## Level Generation

# %% [markdown]
# Flatland 3 Environment Configs:
# https://flatland.aicrowd.com/challenges/flatland3/envconfig.html
#
# ![image.png](attachment:image.png)
#
# Detaillierter in AMLD 2021:
# https://flatland.aicrowd.com/challenges/amld2021/envconfig.html
